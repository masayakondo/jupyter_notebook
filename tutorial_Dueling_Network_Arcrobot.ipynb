# %%
# !apt update
# !apt install xvfb
# !pip install gym-notebook-wrapper
# !pip install pyvirtualdisplay
# !pip install gym==0.9.7
# !pip uninstall matplotlib -y
# !pip install matplotlib==2.2.5
# !pip install JSAnimation
# !pip uninstall pyglet -y
# !pip install pyglet==1.2.4

# %%
# 使用するパッケージの宣言
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym
from pyvirtualdisplay import Display
import gnwrapper
import gym
from collections import namedtuple
import random
import torch
from torch import optim
from torch import nn
import torch.nn.functional as F

d = Display()
d.start()

# %%
# namedtupleを生成
from collections import namedtuple

Transition = namedtuple(
    'Transition', ('state', 'action', 'next_state', 'reward'))

# %%
# 定数の設定
ENV = 'CartPole-v0'  # 使用する課題名
GAMMA = 0.99  # 時間割引率
MAX_STEPS = 200  # 1試行のstep数
NUM_EPISODES = 500  # 最大試行回数

# %%
# 経験を保存するメモリクラスを定義します


class ReplayMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  # メモリの最大長さ
        self.memory = []  # 経験を保存する変数
        self.index = 0  # 保存するindexを示す変数

    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)をメモリに保存する'''

        if len(self.memory) < self.capacity:
            self.memory.append(None)  # メモリが満タンでないときは足す

        # namedtupleのTransitionを使用し、値とフィールド名をペアにして保存します
        self.memory[self.index] = Transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity  # 保存するindexを1つずらす

    def sample(self, batch_size):
        '''batch_size分だけ、ランダムに保存内容を取り出す'''
        return random.sample(self.memory, batch_size)

    def __len__(self):
        '''関数lenに対して、現在の変数memoryの長さを返す'''
        return len(self.memory)

# %%
# Dueling Network型のディープ・ニューラルネットワークの構築
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):

    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        # Dueling Network
        self.fc3_adv = nn.Linear(n_mid, n_out)  # Advantage側
        self.fc3_v = nn.Linear(n_mid, 1)  # 価値V側

    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))

        adv = self.fc3_adv(h2)  # この出力はReLUしない
        val = self.fc3_v(h2).expand(-1, adv.size(1))  # この出力はReLUしない
        # valはadvと足し算するために、サイズを[minibatchx1]から[minibatchx2]にexpandする
        # adv.size(1)は出力する行動の種類数の2

        output = val + adv - adv.mean(1, keepdim=True).expand(-1, adv.size(1))
        # val+advからadvの平均値を引き算する
        # adv.mean(1, keepdim=True) で列方向(行動の種類方向)に平均し、サイズが[minibatch×1]
        # expandで展開して、サイズ[minibatchx2]

        return output

# %%
# エージェントが持つ脳となるクラスです、DDQNを実行します

import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000


class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得

        # 経験を記憶するメモリオブジェクトを生成
        self.memory = ReplayMemory(CAPACITY)

        # ニューラルネットワークを構築
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)  # Netクラスを使用
        self.target_q_network = Net(n_in, n_mid, n_out)  # Netクラスを使用
        print(self.main_q_network)  # ネットワークの形を出力

        # 最適化手法の設定
        self.optimizer = optim.Adam(
            self.main_q_network.parameters(), lr=0.0001)

    def replay(self):
        '''Experience Replayでネットワークの結合パラメータを学習'''

        # 1. メモリサイズの確認
        if len(self.memory) < BATCH_SIZE:
            return

        # 2. ミニバッチの作成
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()

        # 3. 教師信号となるQ(s_t, a_t)値を求める
        self.expected_state_action_values = self.get_expected_state_action_values()

        # 4. 結合パラメータの更新
        self.update_main_q_network()

    def decide_action(self, state, episode):
        '''現在の状態に応じて、行動を決定する'''
        # ε-greedy法で徐々に最適行動のみを採用する
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()  # ネットワークを推論モードに切り替える
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
            # ネットワークの出力の最大値のindexを取り出します = max(1)[1]
            # .view(1,1)は[torch.LongTensor of size 1]　を size 1x1 に変換します

        else:
            # 0,1の行動をランダムに返す
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 0,1の行動をランダムに返す
            # actionは[torch.LongTensor of size 1x1]の形になります

        return action

    def make_minibatch(self):
        '''2. ミニバッチの作成'''

        # 2.1 メモリからミニバッチ分のデータを取り出す
        transitions = self.memory.sample(BATCH_SIZE)

        # 2.2 各変数をミニバッチに対応する形に変形
        # transitionsは1stepごとの(state, action, state_next, reward)が、BATCH_SIZE分格納されている
        # つまり、(state, action, state_next, reward)×BATCH_SIZE
        # これをミニバッチにしたい。つまり
        # (state×BATCH_SIZE, action×BATCH_SIZE, state_next×BATCH_SIZE, reward×BATCH_SIZE)にする
        batch = Transition(*zip(*transitions))

        # 2.3 各変数の要素をミニバッチに対応する形に変形し、ネットワークで扱えるようVariableにする
        # 例えばstateの場合、[torch.FloatTensor of size 1x4]がBATCH_SIZE分並んでいるのですが、
        # それを torch.FloatTensor of size BATCH_SIZEx4 に変換します
        # 状態、行動、報酬、non_finalの状態のミニバッチのVariableを作成
        # catはConcatenates（結合）のことです。
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''3. 教師信号となるQ(s_t, a_t)値を求める'''

        # 3.1 ネットワークを推論モードに切り替える
        self.main_q_network.eval()
        self.target_q_network.eval()

        # 3.2 ネットワークが出力したQ(s_t, a_t)を求める
        # self.model(state_batch)は、右左の両方のQ値を出力しており
        # [torch.FloatTensor of size BATCH_SIZEx2]になっている。
        # ここから実行したアクションa_tに対応するQ値を求めるため、action_batchで行った行動a_tが右か左かのindexを求め
        # それに対応するQ値をgatherでひっぱり出す。
        self.state_action_values = self.main_q_network(
            self.state_batch).gather(1, self.action_batch)

        # 3.3 max{Q(s_t+1, a)}値を求める。ただし次の状態があるかに注意。

        # cartpoleがdoneになっておらず、next_stateがあるかをチェックするインデックスマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None,
                                                    self.batch.next_state)))
        # まずは全部0にしておく
        next_state_values = torch.zeros(BATCH_SIZE)

        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)

        # 次の状態での最大Q値の行動a_mをMain Q-Networkから求める
        # 最後の[1]で行動に対応したindexが返る
        a_m[non_final_mask] = self.main_q_network(
            self.non_final_next_states).detach().max(1)[1]

        # 次の状態があるものだけにフィルターし、size 32を32×1へ
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        # 次の状態があるindexの、行動a_mのQ値をtarget Q-Networkから求める
        # detach()で取り出す
        # squeeze()でsize[minibatch×1]を[minibatch]に。
        next_state_values[non_final_mask] = self.target_q_network(
            self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        # 3.4 教師となるQ(s_t, a_t)値を、Q学習の式から求める
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values

        return expected_state_action_values

    def update_main_q_network(self):
        '''4. 結合パラメータの更新'''

        # 4.1 ネットワークを訓練モードに切り替える
        self.main_q_network.train()

        # 4.2 損失関数を計算する（smooth_l1_lossはHuberloss）
        # expected_state_action_valuesは
        # sizeが[minbatch]になっているので、unsqueezeで[minibatch x 1]へ
        loss = F.smooth_l1_loss(self.state_action_values,
                                self.expected_state_action_values.unsqueeze(1))

        # 4.3 結合パラメータを更新する
        self.optimizer.zero_grad()  # 勾配をリセット
        loss.backward()  # バックプロパゲーションを計算
        self.optimizer.step()  # 結合パラメータを更新

    def update_target_q_network(self):  # DDQNで追加
        '''Target Q-NetworkをMainと同じにする'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %%
# CartPoleで動くエージェントクラスです、棒付き台車そのものになります


class Agent:
    def __init__(self, num_states, num_actions):
        '''課題の状態と行動の数を設定する'''
        self.brain = Brain(num_states, num_actions)  # エージェントが行動を決定するための頭脳を生成

    def update_q_function(self):
        '''Q関数を更新する'''
        self.brain.replay()

    def get_action(self, state, episode):
        '''行動を決定する'''
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        '''memoryオブジェクトに、state, action, state_next, rewardの内容を保存する'''
        self.brain.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        '''Target Q-NetworkをMain Q-Networkと同じに更新'''
        self.brain.update_target_q_network()

# %%
# CartPoleを実行する環境のクラスです


class Environment:

    def __init__(self):
        # self.env = gym.make(ENV)  # 実行する課題を設定
        self.env = gnwrapper.Monitor(gym.make(ENV),directory="./",force=True) 
        num_states = self.env.observation_space.shape[0]  # 課題の状態と行動の数を設定
        num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の2を取得
        # 環境内で行動するAgentを生成
        self.agent = Agent(num_states, num_actions)

    def run(self):
        '''実行'''
        episode_10_list = np.zeros(10)  # 10試行分の立ち続けたstep数を格納し、平均ステップ数を出力に利用
        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        episode_final = False  # 最後の試行フラグ
        frames = []  # 最後の試行を動画にするために画像を格納する変数

        for episode in range(NUM_EPISODES):  # 試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化

            state = observation  # 観測をそのまま状態sとして使用
            state = torch.from_numpy(state).type(
                torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
            state = torch.unsqueeze(state, 0)  # size 4をsize 1x4に変換

            for step in range(MAX_STEPS):  # 1エピソードのループ
                
                # 動画描画をコメントアウトしています
                #if episode_final is True:  # 最終試行ではframesに各時刻の画像を追加していく
                    # frames.append(self.env.render(mode='rgb_array'))
                    
                action = self.agent.get_action(state, episode)  # 行動を求める

                # 行動a_tの実行により、s_{t+1}とdoneフラグを求める
                # actionから.item()を指定して、中身を取り出す
                observation_next, _, done, _ = self.env.step(
                    action.item())  # rewardとinfoは使わないので_にする

                # 報酬を与える。さらにepisodeの終了評価と、state_nextを設定する
                if done:  # ステップ数が200経過するか、一定角度以上傾くとdoneはtrueになる
                    state_next = None  # 次の状態はないので、Noneを格納

                    # 直近10episodeの立てたstep数リストに追加
                    episode_10_list = np.hstack(
                        (episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor(
                            [-1.0])  # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0  # 連続成功記録をリセット
                    else:
                        reward = torch.FloatTensor([1.0])  # 立ったまま終了時は報酬1を与える
                        complete_episodes = complete_episodes + 1  # 連続記録を更新
                else:
                    reward = torch.FloatTensor([0.0])  # 普段は報酬0
                    state_next = observation_next  # 観測をそのまま状態とする
                    state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
                    state_next = torch.unsqueeze(state_next, 0)  # size 4をsize 1x4に変換

                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)

                # Experience ReplayでQ関数を更新する
                self.agent.update_q_function()

                # 観測の更新
                state = state_next

                # 終了時の処理
                if done:
                    print('%d Episode: Finished after %d steps：10試行の平均step数 = %.1lf' % (
                        episode, step + 1, episode_10_list.mean()))
                    
                    # DDQNで追加、2試行に1度、Target Q-NetworkをMainと同じにコピーする
                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break
                    
                    
            if episode_final is True:
                # 動画描画をコメントアウトしています
                # 動画を保存と描画
                #display_frames_as_gif(frames)
                self.env.display()
                break

            # 10連続で200step経ち続けたら成功
            if complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
# main クラス
cartpole_env = Environment()
cartpole_env.run()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3_adv): Linear(in_features=32, out_features=2, bias=True)
#   (fc3_v): Linear(in_features=32, out_features=1, bias=True)
# )
# 0 Episode: Finished after 18 steps：10試行の平均step数 = 1.8
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:120: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:123: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# 1 Episode: Finished after 16 steps：10試行の平均step数 = 3.4
# 2 Episode: Finished after 12 steps：10試行の平均step数 = 4.6
# 3 Episode: Finished after 9 steps：10試行の平均step数 = 5.5
# 4 Episode: Finished after 9 steps：10試行の平均step数 = 6.4
# 5 Episode: Finished after 10 steps：10試行の平均step数 = 7.4
# 6 Episode: Finished after 8 steps：10試行の平均step数 = 8.2
# 7 Episode: Finished after 9 steps：10試行の平均step数 = 9.1
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:120: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:123: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# 8 Episode: Finished after 9 steps：10試行の平均step数 = 10.0
# 9 Episode: Finished after 9 steps：10試行の平均step数 = 10.9
# 10 Episode: Finished after 9 steps：10試行の平均step数 = 10.0
# 11 Episode: Finished after 8 steps：10試行の平均step数 = 9.2
# 12 Episode: Finished after 8 steps：10試行の平均step数 = 8.8
# 13 Episode: Finished after 10 steps：10試行の平均step数 = 8.9
# 14 Episode: Finished after 9 steps：10試行の平均step数 = 8.9
# 15 Episode: Finished after 9 steps：10試行の平均step数 = 8.8
# 16 Episode: Finished after 8 steps：10試行の平均step数 = 8.8
# 17 Episode: Finished after 61 steps：10試行の平均step数 = 14.0
# 18 Episode: Finished after 63 steps：10試行の平均step数 = 19.4
# 19 Episode: Finished after 36 steps：10試行の平均step数 = 22.1
# 20 Episode: Finished after 37 steps：10試行の平均step数 = 24.9
# 21 Episode: Finished after 71 steps：10試行の平均step数 = 31.2
# 22 Episode: Finished after 42 steps：10試行の平均step数 = 34.6
# 23 Episode: Finished after 57 steps：10試行の平均step数 = 39.3
# 24 Episode: Finished after 122 steps：10試行の平均step数 = 50.6
# 25 Episode: Finished after 38 steps：10試行の平均step数 = 53.5
# 26 Episode: Finished after 142 steps：10試行の平均step数 = 66.9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:120: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:123: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# 27 Episode: Finished after 38 steps：10試行の平均step数 = 64.6
# 28 Episode: Finished after 30 steps：10試行の平均step数 = 61.3
# 29 Episode: Finished after 66 steps：10試行の平均step数 = 64.3
# 30 Episode: Finished after 25 steps：10試行の平均step数 = 63.1
# 31 Episode: Finished after 65 steps：10試行の平均step数 = 62.5
# 32 Episode: Finished after 31 steps：10試行の平均step数 = 61.4
# 33 Episode: Finished after 36 steps：10試行の平均step数 = 59.3
# 34 Episode: Finished after 141 steps：10試行の平均step数 = 61.2
# 35 Episode: Finished after 52 steps：10試行の平均step数 = 62.6
# 36 Episode: Finished after 33 steps：10試行の平均step数 = 51.7
# 37 Episode: Finished after 41 steps：10試行の平均step数 = 52.0
# 38 Episode: Finished after 42 steps：10試行の平均step数 = 53.2
# 39 Episode: Finished after 45 steps：10試行の平均step数 = 51.1
# 40 Episode: Finished after 32 steps：10試行の平均step数 = 51.8
# 41 Episode: Finished after 60 steps：10試行の平均step数 = 51.3
# 42 Episode: Finished after 79 steps：10試行の平均step数 = 56.1
# 43 Episode: Finished after 40 steps：10試行の平均step数 = 56.5
# 44 Episode: Finished after 71 steps：10試行の平均step数 = 49.5
# 45 Episode: Finished after 63 steps：10試行の平均step数 = 50.6
# 46 Episode: Finished after 56 steps：10試行の平均step数 = 52.9
# 47 Episode: Finished after 30 steps：10試行の平均step数 = 51.8
# 48 Episode: Finished after 43 steps：10試行の平均step数 = 51.9
# 49 Episode: Finished after 31 steps：10試行の平均step数 = 50.5
# 50 Episode: Finished after 54 steps：10試行の平均step数 = 52.7
# 51 Episode: Finished after 26 steps：10試行の平均step数 = 49.3
# 52 Episode: Finished after 51 steps：10試行の平均step数 = 46.5
# 53 Episode: Finished after 49 steps：10試行の平均step数 = 47.4
# 54 Episode: Finished after 24 steps：10試行の平均step数 = 42.7
# 55 Episode: Finished after 50 steps：10試行の平均step数 = 41.4
# 56 Episode: Finished after 54 steps：10試行の平均step数 = 41.2
# 57 Episode: Finished after 43 steps：10試行の平均step数 = 42.5
# 58 Episode: Finished after 41 steps：10試行の平均step数 = 42.3
# 59 Episode: Finished after 42 steps：10試行の平均step数 = 43.4
# 60 Episode: Finished after 39 steps：10試行の平均step数 = 41.9
# 61 Episode: Finished after 48 steps：10試行の平均step数 = 44.1
# 62 Episode: Finished after 51 steps：10試行の平均step数 = 44.1
# 63 Episode: Finished after 44 steps：10試行の平均step数 = 43.6
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:120: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:123: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# 64 Episode: Finished after 41 steps：10試行の平均step数 = 45.3
# 65 Episode: Finished after 42 steps：10試行の平均step数 = 44.5
# 66 Episode: Finished after 38 steps：10試行の平均step数 = 42.9
# 67 Episode: Finished after 38 steps：10試行の平均step数 = 42.4
# 68 Episode: Finished after 46 steps：10試行の平均step数 = 42.9
# 69 Episode: Finished after 44 steps：10試行の平均step数 = 43.1
# 70 Episode: Finished after 42 steps：10試行の平均step数 = 43.4
# 71 Episode: Finished after 41 steps：10試行の平均step数 = 42.7
# 72 Episode: Finished after 42 steps：10試行の平均step数 = 41.8
# 73 Episode: Finished after 43 steps：10試行の平均step数 = 41.7
# 74 Episode: Finished after 33 steps：10試行の平均step数 = 40.9
# 75 Episode: Finished after 36 steps：10試行の平均step数 = 40.3
# 76 Episode: Finished after 43 steps：10試行の平均step数 = 40.8
# 77 Episode: Finished after 46 steps：10試行の平均step数 = 41.6
# 78 Episode: Finished after 41 steps：10試行の平均step数 = 41.1
# 79 Episode: Finished after 33 steps：10試行の平均step数 = 40.0
# 80 Episode: Finished after 38 steps：10試行の平均step数 = 39.6
# 81 Episode: Finished after 34 steps：10試行の平均step数 = 38.9
# 82 Episode: Finished after 46 steps：10試行の平均step数 = 39.3
# 83 Episode: Finished after 44 steps：10試行の平均step数 = 39.4
# 84 Episode: Finished after 34 steps：10試行の平均step数 = 39.5
# 85 Episode: Finished after 44 steps：10試行の平均step数 = 40.3
# 86 Episode: Finished after 39 steps：10試行の平均step数 = 39.9
# 87 Episode: Finished after 32 steps：10試行の平均step数 = 38.5
# 88 Episode: Finished after 29 steps：10試行の平均step数 = 37.3
# 89 Episode: Finished after 37 steps：10試行の平均step数 = 37.7
# 90 Episode: Finished after 157 steps：10試行の平均step数 = 49.6
# 91 Episode: Finished after 43 steps：10試行の平均step数 = 50.5
# 92 Episode: Finished after 150 steps：10試行の平均step数 = 60.9
# 93 Episode: Finished after 200 steps：10試行の平均step数 = 76.5
# 94 Episode: Finished after 180 steps：10試行の平均step数 = 91.1
# 95 Episode: Finished after 179 steps：10試行の平均step数 = 104.6
# 96 Episode: Finished after 200 steps：10試行の平均step数 = 120.7
# 97 Episode: Finished after 200 steps：10試行の平均step数 = 137.5
# 98 Episode: Finished after 200 steps：10試行の平均step数 = 154.6
# 99 Episode: Finished after 200 steps：10試行の平均step数 = 170.9
# 100 Episode: Finished after 200 steps：10試行の平均step数 = 175.2
# 101 Episode: Finished after 200 steps：10試行の平均step数 = 190.9
# 102 Episode: Finished after 200 steps：10試行の平均step数 = 195.9
# 103 Episode: Finished after 173 steps：10試行の平均step数 = 193.2
# 104 Episode: Finished after 200 steps：10試行の平均step数 = 195.2
# 105 Episode: Finished after 199 steps：10試行の平均step数 = 197.2
# 106 Episode: Finished after 170 steps：10試行の平均step数 = 194.2
# 107 Episode: Finished after 125 steps：10試行の平均step数 = 186.7
# 108 Episode: Finished after 87 steps：10試行の平均step数 = 175.4
# 109 Episode: Finished after 86 steps：10試行の平均step数 = 164.0
# 110 Episode: Finished after 88 steps：10試行の平均step数 = 152.8
# 111 Episode: Finished after 96 steps：10試行の平均step数 = 142.4
# 112 Episode: Finished after 91 steps：10試行の平均step数 = 131.5
# 113 Episode: Finished after 91 steps：10試行の平均step数 = 123.3
# 114 Episode: Finished after 103 steps：10試行の平均step数 = 113.6
# 115 Episode: Finished after 119 steps：10試行の平均step数 = 105.6
# 116 Episode: Finished after 119 steps：10試行の平均step数 = 100.5
# 117 Episode: Finished after 109 steps：10試行の平均step数 = 98.9
# 118 Episode: Finished after 106 steps：10試行の平均step数 = 100.8
# 119 Episode: Finished after 89 steps：10試行の平均step数 = 101.1
# 120 Episode: Finished after 87 steps：10試行の平均step数 = 101.0
# 121 Episode: Finished after 110 steps：10試行の平均step数 = 102.4
# 122 Episode: Finished after 98 steps：10試行の平均step数 = 103.1
# 123 Episode: Finished after 109 steps：10試行の平均step数 = 104.9
# 124 Episode: Finished after 139 steps：10試行の平均step数 = 108.5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:120: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:123: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:25.)
# 125 Episode: Finished after 142 steps：10試行の平均step数 = 110.8
# 126 Episode: Finished after 141 steps：10試行の平均step数 = 113.0
# 127 Episode: Finished after 145 steps：10試行の平均step数 = 116.6
# 128 Episode: Finished after 123 steps：10試行の平均step数 = 118.3
# 129 Episode: Finished after 141 steps：10試行の平均step数 = 123.5
# 130 Episode: Finished after 153 steps：10試行の平均step数 = 130.1
# 131 Episode: Finished after 133 steps：10試行の平均step数 = 132.4
# 132 Episode: Finished after 118 steps：10試行の平均step数 = 134.4
# 133 Episode: Finished after 122 steps：10試行の平均step数 = 135.7
# 134 Episode: Finished after 95 steps：10試行の平均step数 = 131.3
# 135 Episode: Finished after 139 steps：10試行の平均step数 = 131.0
# 136 Episode: Finished after 133 steps：10試行の平均step数 = 130.2
# 137 Episode: Finished after 115 steps：10試行の平均step数 = 127.2
# 138 Episode: Finished after 129 steps：10試行の平均step数 = 127.8
# 139 Episode: Finished after 132 steps：10試行の平均step数 = 126.9
# 140 Episode: Finished after 174 steps：10試行の平均step数 = 129.0
# 141 Episode: Finished after 121 steps：10試行の平均step数 = 127.8
# 142 Episode: Finished after 141 steps：10試行の平均step数 = 130.1
# 143 Episode: Finished after 164 steps：10試行の平均step数 = 134.3
# 144 Episode: Finished after 158 steps：10試行の平均step数 = 140.6
# 145 Episode: Finished after 137 steps：10試行の平均step数 = 140.4
# 146 Episode: Finished after 157 steps：10試行の平均step数 = 142.8
# 147 Episode: Finished after 140 steps：10試行の平均step数 = 145.3
# 148 Episode: Finished after 163 steps：10試行の平均step数 = 148.7
# 149 Episode: Finished after 186 steps：10試行の平均step数 = 154.1
# 150 Episode: Finished after 200 steps：10試行の平均step数 = 156.7
# 151 Episode: Finished after 177 steps：10試行の平均step数 = 162.3
# 152 Episode: Finished after 122 steps：10試行の平均step数 = 160.4
# 153 Episode: Finished after 164 steps：10試行の平均step数 = 160.4
# 154 Episode: Finished after 138 steps：10試行の平均step数 = 158.4
# 155 Episode: Finished after 127 steps：10試行の平均step数 = 157.4
# 156 Episode: Finished after 88 steps：10試行の平均step数 = 150.5
# 157 Episode: Finished after 99 steps：10試行の平均step数 = 146.4
# 158 Episode: Finished after 111 steps：10試行の平均step数 = 141.2
# 159 Episode: Finished after 91 steps：10試行の平均step数 = 131.7
# 160 Episode: Finished after 147 steps：10試行の平均step数 = 126.4
# 161 Episode: Finished after 150 steps：10試行の平均step数 = 123.7
# 162 Episode: Finished after 180 steps：10試行の平均step数 = 129.5
# 163 Episode: Finished after 137 steps：10試行の平均step数 = 126.8
# 164 Episode: Finished after 200 steps：10試行の平均step数 = 133.0
# 165 Episode: Finished after 200 steps：10試行の平均step数 = 140.3
# 166 Episode: Finished after 200 steps：10試行の平均step数 = 151.5
# 167 Episode: Finished after 200 steps：10試行の平均step数 = 161.6
# 168 Episode: Finished after 177 steps：10試行の平均step数 = 168.2
# 169 Episode: Finished after 200 steps：10試行の平均step数 = 179.1
# 170 Episode: Finished after 200 steps：10試行の平均step数 = 184.4
# 171 Episode: Finished after 136 steps：10試行の平均step数 = 183.0
# 172 Episode: Finished after 200 steps：10試行の平均step数 = 185.0
# 173 Episode: Finished after 171 steps：10試行の平均step数 = 188.4
# 174 Episode: Finished after 200 steps：10試行の平均step数 = 188.4
# 175 Episode: Finished after 125 steps：10試行の平均step数 = 180.9
# 176 Episode: Finished after 88 steps：10試行の平均step数 = 169.7
# 177 Episode: Finished after 200 steps：10試行の平均step数 = 169.7
# 178 Episode: Finished after 61 steps：10試行の平均step数 = 158.1
# 179 Episode: Finished after 120 steps：10試行の平均step数 = 150.1
# 180 Episode: Finished after 51 steps：10試行の平均step数 = 135.2
# 181 Episode: Finished after 31 steps：10試行の平均step数 = 124.7
# 182 Episode: Finished after 51 steps：10試行の平均step数 = 109.8
# 183 Episode: Finished after 85 steps：10試行の平均step数 = 101.2
# 184 Episode: Finished after 91 steps：10試行の平均step数 = 90.3
# 185 Episode: Finished after 200 steps：10試行の平均step数 = 97.8
# 186 Episode: Finished after 200 steps：10試行の平均step数 = 109.0
# 187 Episode: Finished after 200 steps：10試行の平均step数 = 109.0
# 188 Episode: Finished after 200 steps：10試行の平均step数 = 122.9
# 189 Episode: Finished after 200 steps：10試行の平均step数 = 130.9
# 190 Episode: Finished after 200 steps：10試行の平均step数 = 145.8
# 191 Episode: Finished after 200 steps：10試行の平均step数 = 162.7
# 192 Episode: Finished after 200 steps：10試行の平均step数 = 177.6
# 193 Episode: Finished after 200 steps：10試行の平均step数 = 189.1
# 194 Episode: Finished after 200 steps：10試行の平均step数 = 200.0
# 10回連続成功
# 195 Episode: Finished after 200 steps：10試行の平均step数 = 200.0
# 'openaigym.video.1.59.video000000.mp4'
#             <video alt="test" controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#             </video>
# 'openaigym.video.1.59.video000001.mp4'
#             <video alt="test" controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#             </video>
# 'openaigym.video.1.59.video000008.mp4'
#             <video alt="test" controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#             </video>
# 'openaigym.video.1.59.video000027.mp4'
#             <video alt="test" controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#             </video>
# 'openaigym.video.1.59.video000064.mp4'
#             <video alt="test" controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#             </video>
# 'openaigym.video.1.59.video000125.mp4'
#             <video alt="test" controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4" />
#             </video>
