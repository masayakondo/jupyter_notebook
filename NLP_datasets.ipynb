# %% [markdown]
# # huggingfaceの簡単にデータセットをロードできるライブラリの紹介
# - https://tma15.github.io/blog/2020/05/17/%E8%87%AA%E7%84%B6%E8%A8%80%E8%AA%9E%E5%87%A6%E7%90%86%E5%85%AC%E9%96%8B%E3%81%95%E3%82%8C%E3%81%A6%E3%81%84%E3%82%8B%E3%83%87%E3%83%BC%E3%82%BF%E3%82%BB%E3%83%83%E3%83%88%E3%82%92%E7%B0%A1%E5%8D%98%E3%81%AB%E4%BD%BF%E3%81%86%E3%83%A9%E3%82%A4%E3%83%96%E3%83%A9%E3%83%AA-nlp-%E3%81%AE%E7%B4%B9%E4%BB%8B/
# - https://github.com/huggingface/datasets

# %%
# pipでインストールできる
# !pip install datasets
# Out:
# ...
#      |████████████████████████████████| 184kB 8.5MB/s
# ...
#      |████████████████████████████████| 20.7MB 1.4MB/s
# ...
#      |████████████████████████████████| 112kB 63.4MB/s
# ...
#      |████████████████████████████████| 245kB 52.9MB/s
# ...
#   Found existing installation: pyarrow 0.14.1
#     Uninstalling pyarrow-0.14.1:
#       Successfully uninstalled pyarrow-0.14.1
# ...

# %%
import datasets
# 公開されているデータセット一覧
print(datasets.list_datasets()[:10])
print(len(datasets.list_datasets()))
# Out:
# ['acronym_identification', 'ade_corpus_v2', 'adversarial_qa', 'aeslc', 'afrikaans_ner_corpus', 'ag_news', 'ai2_arc', 'air_dialogue', 'ajgt_twitter_ar', 'allegro_reviews']
# 680

# %%
# load_datasetで簡単にダウンロードできる
emotion_dataset = datasets.load_dataset('emotion')
emotion_train_dataset = datasets.load_dataset('emotion', split='train')
# Out:
# Using custom data configuration default
# Reusing dataset emotion (/root/.cache/huggingface/datasets/emotion/default/0.0.0/aa34462255cd487d04be8387a2d572588f6ceee23f784f37365aa714afeb8fe6)
# Using custom data configuration default
# Reusing dataset emotion (/root/.cache/huggingface/datasets/emotion/default/0.0.0/aa34462255cd487d04be8387a2d572588f6ceee23f784f37365aa714afeb8fe6)

# %%
emotion_train_dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 16000
# })

# %%
# DatasetDict型で取得される
print(emotion_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 16000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
# })

# %%
emotion_dataset['train']['text'][:10]
print(emotion_dataset['train']['label'][:10])
# Out:
# [0, 0, 3, 2, 3, 0, 5, 4, 1, 2]

# %%
set(emotion_dataset['train']['label'])
# Out:
# {0, 1, 2, 3, 4, 5}

# %%
news_dataset = datasets.load_dataset('ag_news')
# Out:
# ...
# Using custom data configuration default
# ...
# Dataset ag_news downloaded and prepared to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/fb5c5e74a110037311ef5e904583ce9f8b9fbc1354290f97b4929f01b3f48b1a. Subsequent calls will reuse this data.

# %%
covid_datasets = datasets.load_dataset('covid_tweets_japanese')
# Out:
# ...
# WARNING:datasets.builder:Using custom data configuration default
# ...
# Dataset covid_tweets_japanese downloaded and prepared to /root/.cache/huggingface/datasets/covid_tweets_japanese/default/1.1.0/bab950f3b4dde131933a4bebd55fe0f164ec925fa34ec401c0ec55ad62f0925a. Subsequent calls will reuse this data.

# %%
datasets.list_metrics()
# Out:
# ['accuracy',
#  'bertscore',
#  'bleu',
#  'bleurt',
#  'comet',
#  'coval',
#  'f1',
#  'gleu',
#  'glue',
#  'indic_glue',
#  'meteor',
#  'precision',
#  'recall',
#  'rouge',
#  'sacrebleu',
#  'seqeval',
#  'squad',
#  'squad_v2',
#  'wer',
#  'xnli']

# %%
data = datasets.load_dataset('emo', 'emo2019')
# Out:
# WARNING:datasets.builder:Reusing dataset emo (/root/.cache/huggingface/datasets/emo/emo2019/1.0.0/2eedb71b1ce4a28c86a941781403b0e0694f9a794ae6a7eba56b686c4c85f12c)
